# %%
import random
import os
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D, Dense, Input

def build_conv1d_tcn_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        Conv1D(filters=64, kernel_size=3, padding='causal', activation='relu', dilation_rate=1),
        Conv1D(filters=64, kernel_size=3, padding='causal', activation='relu', dilation_rate=2),
        Conv1D(filters=32, kernel_size=3, padding='causal', activation='relu', dilation_rate=4),
        GlobalAveragePooling1D(),
        Dense(16, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

# Setup
data_dir = "../windowed_data/6h"
feature_names = ['bg', 'cals', 'dist', 'hr', 'insulin', 'steps']
selected_features = ['bg', 'steps', 'dist', 'insulin']
selected_indices = [feature_names.index(f) for f in selected_features]
all_files = [f for f in os.listdir(data_dir) if f.endswith('.npz')]

results_tcn = {}
tcn_preds = {}

# Train & Evaluate per Patient
for file in all_files:
    pid = file.replace(".npz", "")
    data = np.load(os.path.join(data_dir, file))
    X, y = data['X'], data['y']
    X = X[:, :, selected_indices]

    # Chronological 80/20 split
    split = int(0.8 * len(X))
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    print(f"\nTraining TCN for {pid}...")
    model = build_conv1d_tcn_model(input_shape=(X.shape[1], X.shape[2]))
    model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=1)

    y_pred = model.predict(X_test).flatten()
    rmse_tcn = np.sqrt(mean_squared_error(y_test, y_pred))
    mae_tcn = mean_absolute_error(y_test, y_pred)

    results_tcn[pid] = {"rmse": rmse_tcn, "mae": mae_tcn}
    tcn_preds[pid] = {"y_true": y_test.tolist(), "y_pred": y_pred.tolist()}

    print(f"{pid} - RMSE: {rmse_tcn:.3f} | MAE: {mae_tcn:.3f}")
# Out:
# Training TCN for P01...
# Epoch 1/10
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 18.6424
# Epoch 2/10
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 9.8119
# Epoch 3/10
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 8.4228
# Epoch 4/10
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - loss: 7.3616
# Epoch 5/10
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - loss: 6.1256
# Epoch 6/10
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 34s 15ms/step - loss: 5.5940
# Epoch 7/10
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 34s 24ms/step - loss: 5.1138
# Epoch 8/10
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 36s 20ms/step - loss: 4.9257
# Epoch 9/10
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 30s 21ms/step - loss: 4.4326
# Epoch 10/10
# 1457/1457 ━━━━━━━━━━━━━━━━━━━━ 37s 18ms/step - loss: 4.2447
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# P01 - RMSE: 3.401 | MAE: 2.573
#
# Training TCN for P02...
# Epoch 1/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - loss: 95.3196
# Epoch 2/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - loss: 71.5842
# Epoch 3/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - loss: 52.2107
# Epoch 4/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - loss: 36.4589
# Epoch 5/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - loss: 25.5504
# Epoch 6/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - loss: 17.4666
# Epoch 7/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - loss: 13.0242
# Epoch 8/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 36s 13ms/step - loss: 10.6400
# Epoch 9/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - loss: 10.0721
# Epoch 10/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - loss: 9.9488
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step
# P02 - RMSE: 3.876 | MAE: 3.065
#
# Training TCN for P03...
# Epoch 1/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - loss: 14.4632
# Epoch 2/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - loss: 8.4100
# Epoch 3/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 6.9168
# Epoch 4/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - loss: 6.3650
# Epoch 5/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 5.8124
# Epoch 6/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - loss: 5.2391
# Epoch 7/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 15s 22ms/step - loss: 4.8873
# Epoch 8/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 4.5749
# Epoch 9/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 4.3171
# Epoch 10/10
# 700/700 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 4.0758
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step
# P03 - RMSE: 2.475 | MAE: 1.929
#
# Training TCN for P04...
# Epoch 1/10
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - loss: 8.0757
# Epoch 2/10
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 40s 25ms/step - loss: 5.1489
# Epoch 3/10
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 30s 18ms/step - loss: 4.8074
# Epoch 4/10
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - loss: 4.5390
# Epoch 5/10
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - loss: 4.2660
# Epoch 6/10
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - loss: 3.8943
# Epoch 7/10
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - loss: 3.6665
# Epoch 8/10
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 3.3722
# Epoch 9/10
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - loss: 3.2239
# Epoch 10/10
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 37s 16ms/step - loss: 3.0626
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
# P04 - RMSE: 2.506 | MAE: 1.882
#
# Training TCN for P05...
# Epoch 1/10
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - loss: 13.3326
# Epoch 2/10
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 22s 13ms/step - loss: 5.6804
# Epoch 3/10
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - loss: 4.8470
# Epoch 4/10
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 4.2775
# Epoch 5/10
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 3.8387
# Epoch 6/10
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - loss: 3.5204
# Epoch 7/10
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 35s 22ms/step - loss: 3.2806
# Epoch 8/10
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 28s 14ms/step - loss: 3.1472
# Epoch 9/10
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 2.9924
# Epoch 10/10
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 28s 17ms/step - loss: 2.8378
# 401/401 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step
# P05 - RMSE: 2.541 | MAE: 1.941
#
# Training TCN for P06...
# Epoch 1/10
# 1442/1442 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - loss: 17.5194
# Epoch 2/10
# 1442/1442 ━━━━━━━━━━━━━━━━━━━━ 33s 11ms/step - loss: 8.4320
# Epoch 3/10
# 1442/1442 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - loss: 6.9177
# Epoch 4/10
# 1442/1442 ━━━━━━━━━━━━━━━━━━━━ 40s 19ms/step - loss: 6.1661
# Epoch 5/10
# 1442/1442 ━━━━━━━━━━━━━━━━━━━━ 34s 14ms/step - loss: 5.3591
# Epoch 6/10
# 1442/1442 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 4.8884
# Epoch 7/10
# 1442/1442 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - loss: 4.5917
# Epoch 8/10
# 1442/1442 ━━━━━━━━━━━━━━━━━━━━ 26s 18ms/step - loss: 4.2411
# Epoch 9/10
# 1442/1442 ━━━━━━━━━━━━━━━━━━━━ 30s 10ms/step - loss: 4.0801
# Epoch 10/10
# 1442/1442 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - loss: 3.8792
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# P06 - RMSE: 2.885 | MAE: 2.241
#
# Training TCN for P07...
# Epoch 1/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 26s 15ms/step - loss: 99.9388
# Epoch 2/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - loss: 75.6670
# Epoch 3/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - loss: 55.9587
# Epoch 4/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - loss: 40.6655
# Epoch 5/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - loss: 29.4291
# Epoch 6/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 21.8598
# Epoch 7/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - loss: 17.1315
# Epoch 8/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - loss: 14.9240
# Epoch 9/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - loss: 14.1632
# Epoch 10/10
# 1506/1506 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 14.1599
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# P07 - RMSE: 3.923 | MAE: 3.205
#
# Training TCN for P10...
# Epoch 1/10
# 1472/1472 ━━━━━━━━━━━━━━━━━━━━ 36s 22ms/step - loss: 9.2580
# Epoch 2/10
# 1472/1472 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - loss: 2.4104
# Epoch 3/10
# 1472/1472 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - loss: 2.4017
# Epoch 4/10
# 1472/1472 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 2.2216
# Epoch 5/10
# 1472/1472 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - loss: 2.1044
# Epoch 6/10
# 1472/1472 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - loss: 2.0772
# Epoch 7/10
# 1472/1472 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - loss: 1.9286
# Epoch 8/10
# 1472/1472 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - loss: 1.8907
# Epoch 9/10
# 1472/1472 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 1.7773
# Epoch 10/10
# 1472/1472 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 1.7388
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# P10 - RMSE: 1.992 | MAE: 1.526
#
# Training TCN for P11...
# Epoch 1/10
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - loss: 10.3413
# Epoch 2/10
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 5.7929
# Epoch 3/10
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - loss: 5.0537
# Epoch 4/10
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - loss: 4.4725
# Epoch 5/10
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 4.1275
# Epoch 6/10
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 3.7556
# Epoch 7/10
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - loss: 3.6536
# Epoch 8/10
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 25s 15ms/step - loss: 3.4965
# Epoch 9/10
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - loss: 3.4391
# Epoch 10/10
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - loss: 3.3186
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
# P11 - RMSE: 2.125 | MAE: 1.661
#
# Training TCN for P12...
# Epoch 1/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - loss: 8.5208
# Epoch 2/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 4.6695
# Epoch 3/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 3.8657
# Epoch 4/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 40s 13ms/step - loss: 3.2151
# Epoch 5/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 2.8957
# Epoch 6/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - loss: 2.7022
# Epoch 7/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 2.4202
# Epoch 8/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 2.3204
# Epoch 9/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - loss: 2.0752
# Epoch 10/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - loss: 1.9890
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
# P12 - RMSE: 2.129 | MAE: 1.640
#
# Training TCN for P13...
# Epoch 1/10
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - loss: 77.2192
# Epoch 2/10
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 66.7850
# Epoch 3/10
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 57.1198
# Epoch 4/10
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 48.6154
# Epoch 5/10
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 41.6275
# Epoch 6/10
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 35.0271
# Epoch 7/10
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - loss: 29.5881
# Epoch 8/10
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 24.4742
# Epoch 9/10
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 20.5182
# Epoch 10/10
# 682/682 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - loss: 17.0673
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# P13 - RMSE: 3.725 | MAE: 2.983
#
# Training TCN for P15...
# Epoch 1/10
# 1624/1624 ━━━━━━━━━━━━━━━━━━━━ 31s 14ms/step - loss: 77.2128
# Epoch 2/10
# 1624/1624 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 54.3300
# Epoch 3/10
# 1624/1624 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 37.7406
# Epoch 4/10
# 1624/1624 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 24.8564
# Epoch 5/10
# 1624/1624 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 16.7456
# Epoch 6/10
# 1624/1624 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - loss: 11.9775
# Epoch 7/10
# 1624/1624 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 9.9904
# Epoch 8/10
# 1624/1624 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 9.6953
# Epoch 9/10
# 1624/1624 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 9.5523
# Epoch 10/10
# 1624/1624 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 9.6225
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# P15 - RMSE: 3.169 | MAE: 2.494
#
# Training TCN for P16...
# Epoch 1/10
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 9.4796
# Epoch 2/10
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - loss: 3.4877
# Epoch 3/10
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 3.0825
# Epoch 4/10
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - loss: 2.7567
# Epoch 5/10
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 2.6094
# Epoch 6/10
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 2.4209
# Epoch 7/10
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - loss: 2.3187
# Epoch 8/10
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 2.2118
# Epoch 9/10
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - loss: 2.0901
# Epoch 10/10
# 1427/1427 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 1.9651
# 357/357 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# P16 - RMSE: 1.883 | MAE: 1.438
#
# Training TCN for P17...
# Epoch 1/10
# 1460/1460 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 93.8969
# Epoch 2/10
# 1460/1460 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 71.1018
# Epoch 3/10
# 1460/1460 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - loss: 52.8687
# Epoch 4/10
# 1460/1460 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 38.7867
# Epoch 5/10
# 1460/1460 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 28.0036
# Epoch 6/10
# 1460/1460 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 20.6770
# Epoch 7/10
# 1460/1460 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - loss: 16.1487
# Epoch 8/10
# 1460/1460 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 14.1130
# Epoch 9/10
# 1460/1460 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - loss: 13.2470
# Epoch 10/10
# 1460/1460 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - loss: 13.1575
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# P17 - RMSE: 2.855 | MAE: 2.254
#
# Training TCN for P18...
# Epoch 1/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 23s 13ms/step - loss: 134.8970
# Epoch 2/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - loss: 104.4648
# Epoch 3/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 79.4130
# Epoch 4/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - loss: 59.3059
# Epoch 5/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 44.5355
# Epoch 6/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - loss: 32.8471
# Epoch 7/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - loss: 25.3851
# Epoch 8/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 21.5747
# Epoch 9/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 20.0965
# Epoch 10/10
# 1608/1608 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 19.4600
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# P18 - RMSE: 4.800 | MAE: 4.408
#
# Training TCN for P19...
# Epoch 1/10
# 1465/1465 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - loss: 76.4186
# Epoch 2/10
# 1465/1465 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - loss: 55.4502
# Epoch 3/10
# 1465/1465 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - loss: 38.8415
# Epoch 4/10
# 1465/1465 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 26.6939
# Epoch 5/10
# 1465/1465 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - loss: 17.9067
# Epoch 6/10
# 1465/1465 ━━━━━━━━━━━━━━━━━━━━ 27s 19ms/step - loss: 12.0356
# Epoch 7/10
# 1465/1465 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - loss: 8.9452
# Epoch 8/10
# 1465/1465 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - loss: 7.8756
# Epoch 9/10
# 1465/1465 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - loss: 7.7343
# Epoch 10/10
# 1465/1465 ━━━━━━━━━━━━━━━━━━━━ 29s 10ms/step - loss: 7.6815
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# P19 - RMSE: 2.755 | MAE: 2.191
#
# Training TCN for P21...
# Epoch 1/10
# 1522/1522 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 24.9335
# Epoch 2/10
# 1522/1522 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 12.5689
# Epoch 3/10
# 1522/1522 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 10.7914
# Epoch 4/10
# 1522/1522 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 9.6490
# Epoch 5/10
# 1522/1522 ━━━━━━━━━━━━━━━━━━━━ 23s 11ms/step - loss: 8.5406
# Epoch 6/10
# 1522/1522 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 7.6623
# Epoch 7/10
# 1522/1522 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - loss: 7.2325
# Epoch 8/10
# 1522/1522 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - loss: 6.9734
# Epoch 9/10
# 1522/1522 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - loss: 6.7070
# Epoch 10/10
# 1522/1522 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - loss: 6.4514
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# P21 - RMSE: 2.605 | MAE: 1.697
#
# Training TCN for P22...
# Epoch 1/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 9.6307
# Epoch 2/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - loss: 6.2634
# Epoch 3/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 5.3209
# Epoch 4/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 4.5840
# Epoch 5/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 4.1744
# Epoch 6/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - loss: 3.8314
# Epoch 7/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - loss: 3.6723
# Epoch 8/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - loss: 3.4200
# Epoch 9/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - loss: 3.2746
# Epoch 10/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - loss: 3.1872
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# P22 - RMSE: 2.363 | MAE: 1.754
#
# Training TCN for P23...
# Epoch 1/10
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 11.0765
# Epoch 2/10
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - loss: 5.0777
# Epoch 3/10
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 4.5375
# Epoch 4/10
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 3.9641
# Epoch 5/10
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 3.7463
# Epoch 6/10
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 3.3161
# Epoch 7/10
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 3.1341
# Epoch 8/10
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - loss: 2.9645
# Epoch 9/10
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 2.5779
# Epoch 10/10
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 2.5640
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# P23 - RMSE: 2.674 | MAE: 2.005
#
# Training TCN for P24...
# Epoch 1/10
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - loss: 8.2243
# Epoch 2/10
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - loss: 5.3112
# Epoch 3/10
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - loss: 4.6041
# Epoch 4/10
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - loss: 4.0807
# Epoch 5/10
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - loss: 3.7361
# Epoch 6/10
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 3.5138
# Epoch 7/10
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 3.2248
# Epoch 8/10
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - loss: 3.1817
# Epoch 9/10
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 3.0506
# Epoch 10/10
# 1514/1514 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - loss: 2.9288
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# P24 - RMSE: 2.340 | MAE: 1.768

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Save results
df_results_tcn = pd.DataFrame(results_tcn).T.round(3)
df_results_tcn.index.name = "Patient ID"

# Results visualisation
# RMSE Plot
df_rmse_sorted_tcn = df_results_tcn.sort_values("rmse")
x_rmse_tcn = np.arange(len(df_rmse_sorted_tcn))
rmse_values_tcn = df_rmse_sorted_tcn["rmse"].values
mean_rmse_tcn = rmse_values_tcn.mean()
std_rmse_tcn = rmse_values_tcn.std()

plt.figure(figsize=(12, 5))
plt.bar(x_rmse_tcn, rmse_values_tcn, color='skyblue')
plt.xticks(x_rmse_tcn, df_rmse_sorted_tcn.index, rotation=45)

# Confidence band 
plt.axhspan(mean_rmse_tcn - std_rmse_tcn, mean_rmse_tcn + std_rmse_tcn, color='red', alpha=0.2, label="±1 SD")
plt.axhline(mean_rmse_tcn, color='red', linestyle='--', label=f"Mean RMSE = {mean_rmse_tcn:.2f}")

plt.title("RMSE per Patient - TCN")
plt.ylabel("RMSE")
plt.legend()
plt.tight_layout()
plt.show()


# MAE Plot
df_mae_sorted_tcn = df_results_tcn.sort_values("mae")
x_mae_tcn = np.arange(len(df_mae_sorted_tcn))
mae_values_tcn = df_mae_sorted_tcn["mae"].values
mean_mae_tcn = mae_values_tcn.mean()
std_mae_tcn = mae_values_tcn.std()

plt.figure(figsize=(12, 5))
plt.bar(x_mae_tcn, mae_values_tcn, color='skyblue')
plt.xticks(x_mae_tcn, df_mae_sorted_tcn.index, rotation=45)

# Confidence band 
plt.axhspan(mean_mae_tcn - std_mae_tcn, mean_mae_tcn + std_mae_tcn, color='green', alpha=0.2, label="±1 SD")
plt.axhline(mean_mae_tcn, color='green', linestyle='--', label=f"Mean MAE = {mean_mae_tcn:.2f}")

plt.title("MAE per Patient - TCN")
plt.ylabel("MAE")
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_results_tcn.to_csv("../output_baseline/tcn_per_patient_results.csv")

with open("../output_baseline/tcn_predictions_per_patient.json", "w") as f:
    json.dump(tcn_preds, f)

print("\nAverage RMSE:", df_results_tcn["rmse"].mean())
print("Average MAE:", df_results_tcn["mae"].mean())
display(df_results_tcn)
# Out:
# Average RMSE: 2.8510999999999997
# Average MAE: 2.2327500000000002
#              rmse    mae
# Patient ID
# P01         3.401  2.573
# P02         3.876  3.065
# P03         2.475  1.929
# P04         2.506  1.882
# P05         2.541  1.941
# P06         2.885  2.241
# P07         3.923  3.205
# P10         1.992  1.526
# P11         2.125  1.661
# P12         2.129  1.640
# P13         3.725  2.983
# P15         3.169  2.494
# P16         1.883  1.438
# P17         2.855  2.254
# P18         4.800  4.408
# P19         2.755  2.191
# P21         2.605  1.697
# P22         2.363  1.754
# P23         2.674  2.005
# P24         2.340  1.768

# %%
# Load TCN predictions
with open("../output_baseline/tcn_predictions_per_patient.json", "r") as f:
    tcn_preds = json.load(f)

# Convert to DataFrame 
rows = []
for pid, data in tcn_preds.items():
    for true_val, pred_val in zip(data["y_true"], data["y_pred"]):
        rows.append({
            "patient_id": pid,
            "true_bg": float(true_val),
            "predicted_bg": float(pred_val)
        })

df_tcn = pd.DataFrame(rows)

# Clarke Error Grid Zone Classification (using mg/dL)
def classify_ceg_zone(true, pred):
    true = float(true)
    pred = float(pred)

    # Zone A: within 20% of reference BG or both < 70
    if (abs(true - pred) <= 20) or (true < 70 and pred < 70) or (true > 180 and pred > 180 and abs(true - pred) <= 20):
        return 'A'
    
    # Zone B: outside 20% but no treatment error (e.g. still within euglycemic range)
    if (true >= 70 and true <= 180 and pred >= 70 and pred <= 180):
        return 'B'
    if (true < 70 and 70 <= pred <= 180):
        return 'B'
    if (true > 180 and 70 <= pred <= 180):
        return 'B'
    
    # Zone E: dangerous confusion
    if (true < 70 and pred > 180) or (true > 180 and pred < 70):
        return 'E'
    
    # Zone D: dangerous failure to detect and treat
    if (true >= 180 and pred <= 180) or (true < 70 and pred >= 70):
        return 'D'
    
    # Zone C: overcorrection / unnecessary treatment
    return 'C'

# Convert mmol/L to mg/dL for Clarke Error Grid
df_tcn["true_bg_mg"] = df_tcn["true_bg"] * 18
df_tcn["predicted_bg_mg"] = df_tcn["predicted_bg"] * 18

# Apply classification
df_tcn["zone"] = df_tcn.apply(lambda row: classify_ceg_zone(row["true_bg_mg"], row["predicted_bg_mg"]), axis=1)

# Per-patient zone summary
ceg_summary_tcn = df_tcn.groupby(["patient_id", "zone"]).size().unstack(fill_value=0)
ceg_summary_tcn["Total"] = ceg_summary_tcn.sum(axis=1)
ceg_summary_percent_tcn = ceg_summary_tcn.div(ceg_summary_tcn["Total"], axis=0) * 100
ceg_summary_percent_tcn = ceg_summary_percent_tcn.round(2)
ceg_summary_percent_tcn.to_csv("../output_baseline/tcn_ceg_zone_summary_per_patient.csv")

print("\nTCN Clarke Error Grid Summary (%):")
display(ceg_summary_percent_tcn)
# Out:
# TCN Clarke Error Grid Summary (%):
# zone            A      B      C     D     E  Total
# patient_id
# P01         27.97  49.80  21.84  0.01  0.38  100.0
# P02         21.72  78.28   0.00  0.00  0.00  100.0
# P03         38.57  43.35  18.01  0.00  0.07  100.0
# P04         40.46  55.09   4.34  0.00  0.11  100.0
# P05         36.54  44.19  19.24  0.00  0.04  100.0
# P06         31.57  42.59  25.72  0.00  0.12  100.0
# P07         17.16  82.84   0.00  0.00  0.00  100.0
# P10         46.11  52.77   1.08  0.00  0.04  100.0
# P11         43.43  39.49  16.98  0.00  0.10  100.0
# P12         43.62  40.59  15.72  0.00  0.06  100.0
# P13         23.79  76.21   0.00  0.00  0.00  100.0
# P15         27.20  72.80   0.00  0.00  0.00  100.0
# P16         49.72  49.87   0.41  0.00  0.00  100.0
# P17         28.96  71.04   0.00  0.00  0.00  100.0
# P18          7.30   0.00  92.03  0.00  0.67  100.0
# P19         28.30  71.70   0.00  0.00  0.00  100.0
# P21         53.93  20.08  25.74  0.00  0.25  100.0
# P22         43.87  46.97   9.09  0.00  0.07  100.0
# P23         37.47  54.77   7.77  0.00  0.00  100.0
# P24         43.40  49.81   6.75  0.00  0.05  100.0

# %%
# Patient-Level Clarke Error Grid Bar Plot
ceg_plot_tcn = ceg_summary_percent_tcn.drop(columns="Total").fillna(0)

plt.figure(figsize=(12, 6))
ceg_plot_tcn.plot(kind="bar", stacked=True, colormap="tab20", figsize=(14, 6))
plt.ylabel("Percentage (%)")
plt.title("Clarke Error Grid Zone Distribution per Patient (TCN)")
plt.legend(title="Zone", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(axis='y')
plt.show()
